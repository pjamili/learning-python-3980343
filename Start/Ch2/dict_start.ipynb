# %%
# LinkedIn Learning Python course by Joe Marini
# Example file for complex types

# %%
# Dictionary: a key-value data structure
mydict = {"one": 1,
          "two": 2, 
          3: "three",
          4.5: ["four", "point", "five"]
}
print(mydict)
# Out:
# {'one': 1, 'two': 2, 3: 'three', 4.5: ['four', 'point', 'five']}

# %%
# dictionaries are accessed via keys
print(mydict["one"])
mydict[4.5] ="four point five"
mydict[4.5]

# %%
# you can also set dictionary data by creating a new key
mydict["newkey"] = "new value"
mydict
# Out:
# {'one': 1,
#  'two': 2,
#  3: 'three',
#  4.5: ['four', 'point', 'five'],
#  'newkey': 'new value'}

# %%
# Trying to access a nonexistent key will produce an error
mydict["nonexistent"] # KeyError: 'nonexistent'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Trying to access a nonexistent key will produce an error
# ----> 2 mydict["nonexistent"] # KeyError: 'nonexistent'
#
# KeyError: 'nonexistent'

# %%
# To avoid this, you can use the "in" operator to see if a key exists

# if "one" in mydict:
#     print("one is a key in mydict")

print("one" in mydict) # True
print("nonexistent" in mydict) # False
# Out:
# True
# False

# %%
# You can retrieve all of the keys and values from a dictionary
mydict.keys()
# Out:
# dict_keys(['one', 'two', 3, 4.5, 'newkey'])

# %%
for k in mydict.keys():
    print(k, ": ", mydict[k])
# Out:
# one :  1
# two :  2
# 3 :  three
# 4.5 :  ['four', 'point', 'five']
# newkey :  new value

# %%
# You can also iterate over all the items in a dictionary
for k, v in mydict.items():
    print(k, ": ", v)
# Out:
# one :  1
# two :  2
# 3 :  three
# 4.5 :  ['four', 'point', 'five']
# newkey :  new value

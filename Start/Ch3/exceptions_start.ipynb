# %%
# LinkedIn Learning Python course by Joe Marini
# Example file for working with Exceptions
#

# Errors can happen in programs, and we need a clean way to handle them
# This code will cause an error because you can't divide by zero:
x = 10 / 0

# Exceptions provide a way of catching errors and then handling them in 
# a separate section of the code to group them together


# You can also catch specific exceptions
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 7
#       1 # LinkedIn Learning Python course by Joe Marini
#       2 # Example file for working with Exceptions
#       3 #
#       4
#       5 # Errors can happen in programs, and we need a clean way to handle them
#       6 # This code will cause an error because you can't divide by zero:
# ----> 7 x = 10 / 0
#       9 # Exceptions provide a way of catching errors and then handling them in
#      10 # a separate section of the code to group them together
#      11
#      12
#      13 # You can also catch specific exceptions
#
# ZeroDivisionError: division by zero
